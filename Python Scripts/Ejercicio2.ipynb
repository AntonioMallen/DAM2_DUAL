# %%
from pickle import TRUE
from random import randint
"""
Yo pondria un valor boolean para cada uno de las salas para saber si esta echa o no, en caso de estar echa,
si se entra a la sala no te pondra la prueba, en caso de no estarlo pondra la prueba dependiendo de la opcion.

"""

def NorteF():
    """
    Un enemigo que atacará al jugador. Si saca 90 o más (sobre 100) 
    el jugador habrá muerto y se le ofrecerá volver a empezar. 
    Tras cada ataque del enemigo, el jugador podrá atacar respondiendo 
    Sí a la pregunta: ¿Quieres defenderte? Si saca más de 60 (sobre 100), 
    habrá derrotado al enemigo y podrá ir a otra habitación. 
    Si dice que No quiere defenderse, huirá a la habitación central pero no habrá derrotado al enemigo 
    y no podrá salir de la mazmorra todavía.
    """
    print("Un enemigo ha aparecido en tu camino")
    salir=False
    Norte=False
    while(Norte==False and salir==False):
        ene=randint(0,100)
        
        print("El enemigo te ha hecho "+str(ene)+ " de daño")
        if(ene>=90):
            print("Has muerto")
            Norte=False
            Sur=False
            Este=False
            Oeste=False
            seg=input("¿Quieres seguir? (S/N)")
            if(seg=="N"):
                jugar=False
                salir=True
        else:
            res=input("¿Quieres defenderte? (S/N)")
            if(res=="S"):
                per=randint(0,100)
                print("Le has hecho "+str(per)+" de daño")
                if(per>60):
                    print("¡Has vencido la sala norte!")
                    return True
            elif(res=="N"):
                print("Huyes hacia la sala central")
                salir=True
            else:
                print("Respuesta no contemplada")


def SurF():
    """
    Un acertijo de entre una lista de 10.
    """

    pregunta=["Hay algo que, aunque te pertenezca, la gente siempre lo utiliza más que tú. ¿Qué es?",
              "Crezco a pesar de no estar vivo. No tengo pulmones, pero para vivir necesito el aire. El agua, aunque no tenga boca, me mata. ¿Qué soy?",
              "Estando roto es más útil que sin romperse. ¿Qué es?",
              "Aparato que vibra y gira, te metes en la boca unas 3 veces al día y mide unos 15 cm. ¿Qué es?",
              "Las personas siempre duermen menos en un mes del año. ¿Cuál es este mes?",
              "Estoy en todo pese a estar en nada. ¿Qué soy?",
              "Te paras cuando está verde y continúas cuando está rojo. ¿Qué es?",
              "¿Qué monte era el más alto del mundo antes de descubrir el Everest?",
              "La señora y el señor Sánchez tienen 6 hijos. Cada hijo tiene una hermana. ¿Cuántas personas hay en la familia Sánchez?",
              "Soy alto siendo joven y corto cuando soy viejo. Resplandezco con la vida y el viento es mi mayor enemigo. ¿Qué soy?"]

    respuesta=["nombre",
               "fuego",
               "huevo",
               "cepillo de dientes electrico",
               "febrero",
               "letra d",
               "sandia",
               "monte everest",
               "9",
               "vela"]
    print("En esta prueba deberas acertar un acertijo")
    acertado=False
    while(acertado==False):
        pre=randint(0,9)
        print(str(pregunta[pre]))
        resp=input("Dime la respuesta")
        resp=resp.lower()
        if(resp==respuesta[pre]):
            acertado=True
            print("Correcto!")
            return True
        else:
            print("No es correcto, ahi va otra")



def EsteF():
    """
    Un cofre con un tesoro para el que habrá que tirar un dado de 100 y sacar (aleatoriamente más) de 63 para abrir.
     Si no se consigue abrir, habrá que esperar 20 segundos antes de volver a intentarlo
    """
    import time
    conseguido=False
    cont = 0
    print("Te has encontrado un cofre magico, para abrirlo necesitas sacar mas de un 63 con este dado")
    while(conseguido==False):
        ale=randint(cont,100)
        print("Has sacado un "+str(ale)+" en el dado")
        if(ale>63):
            print("Lo has conseguido!")
            conseguido=True 
            return True
        else:
            print("Vaya, que mala suerte, vuelve a intentar tras 20 segundos")
            cont+2 # para ayudar al jugador le quitamos dos numeros cada vez que falle dentro de las posibilidades
            time.sleep(20)

def OesteF():
    """
    Una pregunta sacada de una lista de preguntas guardada previamente en una
     variable de tipo lista definida al principio del programa. La pregunta se elegirá aleatoriamente.
    Las preguntas (y la palabra que tendrá que estar en la respuesta, 
    aunque la respuesta podrá contener otras palabras) son:
¿Cuál es el río más largo de España? Ebro
¿Cuál es el río más largo de la península ibérica? Tajo
¿Cuál es el río más largo del mundo? Amazonas
¿Cuál es la montaña más alta de España? Teide
¿Cuál es la montaña más alta del mundo? Everest
¿Cuál es el océano más grande? Pacífico
¿Cuál es el país con más extensión? Rusia
¿Cuál es el país más poblado? India
    """
    pregunta=["¿Cuál es el río más largo de España?",
              "¿Cuál es el río más largo de la península ibérica?",
              "¿Cuál es el río más largo del mundo?",
              "¿Cuál es la montaña más alta de España?",
              "¿Cuál es la montaña más alta del mundo?",
              "¿Cuál es el océano más grande?",
              "¿Cuál es el país con más extensión?",
              "¿Cuál es el país más poblado?"]
    respuesta=["Ebro",
               "Tajo",
               "Amazonas",
               "Teide",
               "Everest",
               "Pacifico",
               "Rusia",
               "India"]
    print("En esta prueba deberas acertar una pregunta generada aleatoriamente")
    acertado=False
    while(acertado==False):
        pre=randint(0,7)
        print(str(pregunta[pre]))
        resp=input("Dime la respuesta")
        if(resp==respuesta[pre]):
            acertado=True
            print("Correcto!")
            return True
        else:
            print("No es correcto, ahi va otra pregunta")


def Ejercicio2():
   
    Norte=False
    Sur=False
    Este=False
    Oeste=False
    jugar=True

    while(jugar):
        
        if(Norte and Sur and Oeste and Este ):
            preg=input("¿Quieres volver a jugar? (S/N)")
            if(preg=="S"):
                Norte=False
                Sur=False
                Este=False
                Oeste=False
                print("Comencemos de nuevo")
            else:
                jugar=False
                print("Has superado todas las pruebas!")
                return
        
        print("La habitacion norte esta: "+ str(Norte))
        print("La habitacion este esta: "+ str(Este))
        print("La habitacion sur esta: "+ str(Sur))
        print("La habitacion oeste esta: "+ str(Oeste))
        sala=input("Dime a que sala deseas entrar: (N,S,E,O)")
        
        if(sala=="N"):
            if(Norte==False):
                if(NorteF()):
                    Norte=True
            else:
                print("Esta prueba ya ha sido superada")
        elif(sala=="E"):
            if(Este==False):
                if(EsteF()):
                    Este=True
            else:
                print("Esta prueba ya ha sido superada")
        elif(sala=="S"):
            if(Sur==False):
                if(SurF()):
                    Sur=True
            else:
                print("Esta prueba ya ha sido superada")
        elif(sala=="O"):
            if(Oeste==False):
                if(OesteF()):
                    Oeste=True
            else:
                print("Esta prueba ya ha sido superada")
            

Ejercicio2()
# Out:
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False
# La habitacion norte esta: False
# La habitacion este esta: False
# La habitacion sur esta: False
# La habitacion oeste esta: False

# %%
tel = {'jack': 4098, 'sape': 4139}
tel['guido'] = 4127
tel
# Out:
# {'jack': 4098, 'sape': 4139, 'guido': 4127}

# %%
with open('workfile','r', encoding="utf-8") as f:
    read_data = f.read()
